# %% [markdown]
# <a href="https://colab.research.google.com/github/marcoscalera/am-turma5/blob/main/am_turma5_aula0804.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 2
b = 3
print(a+b)

def soma(a,b):
  return(a+b)
print(soma(1,2))
# Out:
# 5
# 3

# %% [markdown]
# # Pipeline | Python Básico

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn

# %%
pessoas = ('Homo Sapiens', 'Canis Familiaris', 'Felis Catus')
print(type(pessoas))
print(pessoas)
pessoas[0]
pessoas.index('Felis Catus')
# Out:
# <class 'tuple'>
# ('Homo Sapiens', 'Canis Familiaris', 'Felis Catus')
# 2

# %%
for elemento in pessoas:
  print("Classe Biológica", elemento)
# Out:
# Classe Biológica Homo Sapiens
# Classe Biológica Canis Familiaris
# Classe Biológica Felis Catus

# %%
classes = [{'Homo Eretus':'AC023'},{'Canis Familiaris':'AC028'},{'Ailuropoda Melanoleuca':'AC012'}]
classes
# Out:
# [{'Homo Eretus': 'AC023'},
#  {'Canis Familiaris': 'AC028'},
#  {'Ailuropoda Melanoleuca': 'AC012'}]
